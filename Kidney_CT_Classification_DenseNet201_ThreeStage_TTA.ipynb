# %%
import os
import splitfolders
import random
import sys
import shutil
import logging
import cv2
import requests
import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt
import tensorflow        as tf
from   tensorflow.keras.models        import load_model
from   tensorflow.keras.applications  import VGG16, ResNet50, MobileNetV2,InceptionResNetV2, InceptionV3,DenseNet201, Xception, EfficientNetB0
from   tensorflow.keras.models        import Sequential, Model
from   tensorflow.keras.layers        import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from   tensorflow.keras.preprocessing import image
from   tensorflow.keras.preprocessing.image import ImageDataGenerator
from   keras.callbacks                import EarlyStopping
from   sklearn.metrics                import accuracy_score, confusion_matrix,  precision_score, recall_score, classification_report, f1_score, roc_curve, roc_auc_score, ConfusionMatrixDisplay
from   io                             import BytesIO
from   PIL                            import Image

# %%
# Preprocessing functions
def apply_hu_window(image):
    """
    Applies a soft-tissue window for kidneys.
    """
    # WW ~ 400 HU, WC ~ 50 HU is well suited for kidneys.
    
    img_min = -150
    img_max = 250
    
    windowed_image = np.clip(image, img_min, img_max)
    
    # Normalize to 0-1
    windowed_image = (windowed_image - img_min) / (img_max - img_min)
    
    # Scale to 0-255 and convert to uint8 for CLAHE
    windowed_image = (windowed_image * 255).astype(np.uint8)
    
    return windowed_image

def apply_clahe(image):
    """
    Applies Contrast Limited Adaptive Histogram Equalization (CLAHE).
    Expects a 3-channel RGB image.
    """
    # Convert to LAB color space
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    
    # Apply CLAHE to the L-channel
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    
    # Merge the CLAHE enhanced L-channel back with A and B channels
    limg = cv2.merge((cl, a, b))
    
    # Convert back to RGB
    final_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return final_image

def kidney_preprocessing_pipeline(image):
    """
    Applies the full preprocessing pipeline for kidney CT scans.
    The input image is a NumPy array from ImageDataGenerator.
    """
    # Ensure image is uint8 for the first steps
    if image.dtype != np.uint8:
        image = image.astype(np.uint8)

    # 1. Apply simulated HU Windowing
    windowed_img = apply_hu_window(image)
    
    # 2. Apply CLAHE for contrast enhancement
    clahe_img = apply_clahe(windowed_img)
    
    # 3. Rescale to [0,1] float32 for the model
    final_image = clahe_img.astype(np.float32) / 255.0
    
    return final_image

# %%
print ("Python version is     : " , sys.version   )
print ("tensorflow version is : " , tf.__version__)

# Get detailed information about GPU(s)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print("\nTensorFlow is using the following GPU(s):")
    for gpu in gpus:
        print(gpu)
else:
    print("\nNo GPU detected or TensorFlow is not configured to use one.")
# Out:
# Python version is     :  3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:20:11) [MSC v.1938 64 bit (AMD64)]
# tensorflow version is :  2.18.0
#
# No GPU detected or TensorFlow is not configured to use one.

# %%
environment = 'PC'

if environment =='colab':
  inputFolder  = '/content/dataset/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/'
  outputFolder = '/content/dataset/CT_dataset/'
  results_path  = '/content/dataset/Results/'

else:
  inputFolder  = 'D:\\MyPaper\\Codes\\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone\\CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone'
  outputFolder = 'D:\\MyPaper\\Codes\\dataset\\All\\CT_split\\'
  results_path  = 'D:\\MyPaper\\Codes\\Results\\'

# Validate that input folder exists
if not os.path.exists(inputFolder):
    print(f"ERROR: Input dataset folder not found: {inputFolder}")
    print("Please ensure the dataset is downloaded and extracted to the correct location.")
    sys.exit(1)
    
print(f"Dataset found at: {inputFolder}")
print(f"Output will be saved to: {outputFolder}")
print(f"Results will be saved to: {results_path}")

# %%
train_dir    = outputFolder + 'train'
val_dir      = outputFolder + 'val'
test_dir     = outputFolder + 'test'

classes      = ['Cyst', 'Normal', 'Stone', 'Tumor']
random.seed(42)

IMAGE_WIDTH  = 224
IMAGE_HEIGHT = 224
num_classes  = 4
img_size     = (IMAGE_WIDTH, IMAGE_HEIGHT)
batch_size   = 32

models     = ['VGG16' , 'ResNet50' ,'MobileNetV2' ,'InceptionResNetV2','InceptionV3', 'DenseNet201', 'Xception','EfficientNetB0']
model_name = 'DenseNet201'
results_path= results_path + model_name+"/"

# Ensure results directory exists
os.makedirs(results_path, exist_ok=True)

model_path =  results_path + '_10Epochs.keras'

# %%
# Split dataset into Train (80%), Validation (10%), Test (10%)
splitfolders.ratio(inputFolder, outputFolder, seed=42, ratio=(0.8, 0.1, 0.1))
# Out:
# Copying files: 12446 files [00:15, 798.23 files/s]

# %%
print("Train_dir Subfolders: ", os.listdir(train_dir))
print("Valid_dir Subfolders: ", os.listdir(val_dir))
print("Test_dir Subfolders : ", os.listdir(test_dir))
# Out:
# Train_dir Subfolders:  ['Cyst', 'Normal', 'Stone', 'Tumor']
# Valid_dir Subfolders:  ['Cyst', 'Normal', 'Stone', 'Tumor']
# Test_dir Subfolders :  ['Cyst', 'Normal', 'Stone', 'Tumor']

# %%
model        = DenseNet201(input_shape=(IMAGE_WIDTH , IMAGE_HEIGHT ,3), weights='imagenet', include_top=False, pooling='avg')

for layer in model.layers:
      layer.trainable = False

x     = Flatten()(model.output)
x     = Dense(num_classes, activation = 'softmax')(x)
model = Model(inputs = model.input, outputs = x)

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
# model.summary()

# %%
image_train_gen =ImageDataGenerator(
                                    rotation_range=20,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    horizontal_flip=True,
                                    zoom_range=0.2,
                                    preprocessing_function=kidney_preprocessing_pipeline
                                  )

image_valid_gen =ImageDataGenerator(
                                    preprocessing_function=kidney_preprocessing_pipeline
                                  )

test_datagen = ImageDataGenerator(preprocessing_function=kidney_preprocessing_pipeline)

# %%
train_ds = image_train_gen.flow_from_directory(
                                                train_dir,
                                                target_size= img_size,
                                                batch_size = batch_size,
                                                class_mode = 'sparse',
                                              )

valid_ds = image_valid_gen.flow_from_directory(
                                                val_dir,
                                                target_size= img_size ,
                                                batch_size = batch_size,
                                                class_mode = 'sparse',
                                               )
test_ds = test_datagen.flow_from_directory(
                                            test_dir,
                                            target_size= img_size ,
                                            batch_size = batch_size,
                                            class_mode = 'sparse',
                                            shuffle=False
                                           )
# Out:
# Found 9955 images belonging to 4 classes.
# Found 1242 images belonging to 4 classes.
# Found 1242 images belonging to 4 classes.
# Found 1249 images belonging to 4 classes.
# Found 1249 images belonging to 4 classes.

# %%
#show sample of augmented images
def show_augmented_images(dataset, num_images=6):

    images, labels = next(dataset)
    class_names    = list(dataset.class_indices.keys())

    plt.figure(figsize=(15, 8))

    for i in range(num_images):
        img = images[i]
        
        # The preprocessing function and rescale turn the image into float32.
        # For visualization, we need to handle this.
        # If the image is float, we assume it's in [0,1] range.
        if img.dtype == np.float32 or img.dtype == np.float64:
            # Clip to be safe, then scale to 0-255 and convert to uint8
            img_to_show = (np.clip(img, 0, 1) * 255).astype(np.uint8)
        else:
            img_to_show = img

        label = class_names[int(labels[i])]

        plt.subplot(2, 3, i + 1)
        plt.imshow(img_to_show)
        plt.title(f"Preprocessed - {label}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

show_augmented_images(train_ds, num_images=6)

# %%
# Stage 1: Feature extraction training
print("STAGE 1: FEATURE EXTRACTION - Training classifier head only")

# Enhanced early stopping for Stage 1
EarlyStoppingMonitor = EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)

# Train for 10 epochs (optimal for feature extraction phase)
print("Training classifier head for up to 10 epochs...")
history = model.fit(
    train_ds, 
    epochs=10,
    validation_data=valid_ds, 
    callbacks=[EarlyStoppingMonitor],
    verbose=1
)

print(f"Stage 1 completed after {len(history.history['loss'])} epochs")

# %%
# Check model training status
weights = model.get_weights()
if any(w.size > 0 for w in weights):
    print("Model is trained and ready")
else:
    print("Model is not trained")
# Out:
# Model is trained.

# %%
# Model architecture analysis for fine-tuning
print("ANALYZING MODEL STRUCTURE FOR FINE-TUNING")

print(f"Model type: {type(model)}")
print(f"Number of layers in main model: {len(model.layers)}")

print("\nMain model layers:")
for i, layer in enumerate(model.layers):
    layer_info = f"  Layer {i}: {layer.name} ({type(layer).__name__})"
    if hasattr(layer, 'layers'):
        layer_info += f" - contains {len(layer.layers)} sublayers"
    print(layer_info)

# Check for the DenseNet backbone
densenet_layer = None
for i, layer in enumerate(model.layers):
    if 'densenet' in layer.name.lower():
        densenet_layer = layer
        print(f"\nFound DenseNet at index {i}: {layer.name}")
        break

if densenet_layer and hasattr(densenet_layer, 'layers'):
    print(f"DenseNet has {len(densenet_layer.layers)} layers")
    print("First few DenseNet layers:")
    for i, layer in enumerate(densenet_layer.layers[:5]):
        print(f"  DenseNet Layer {i}: {layer.name}")
    print("Last few DenseNet layers:")
    for i, layer in enumerate(densenet_layer.layers[-5:]):
        actual_index = len(densenet_layer.layers) - 5 + i
        print(f"  DenseNet Layer {actual_index}: {layer.name}")
# Out:
# ============================================================
# DIAGNOSING MODEL STRUCTURE FOR STAGE 2
# ============================================================
# Model type: <class 'keras.src.models.functional.Functional'>
# Number of layers in main model: 710
#
# Main model layers:
#   Layer 0: input_layer (InputLayer)
#   Layer 1: zero_padding2d (ZeroPadding2D)
#   Layer 2: conv1_conv (Conv2D)
#   Layer 3: conv1_bn (BatchNormalization)
#   Layer 4: conv1_relu (Activation)
#   Layer 5: zero_padding2d_1 (ZeroPadding2D)
#   Layer 6: pool1 (MaxPooling2D)
#   Layer 7: conv2_block1_0_bn (BatchNormalization)
#   Layer 8: conv2_block1_0_relu (Activation)
#   Layer 9: conv2_block1_1_conv (Conv2D)
#   Layer 10: conv2_block1_1_bn (BatchNormalization)
#   Layer 11: conv2_block1_1_relu (Activation)
#   Layer 12: conv2_block1_2_conv (Conv2D)
#   Layer 13: conv2_block1_concat (Concatenate)
#   Layer 14: conv2_block2_0_bn (BatchNormalization)
#   Layer 15: conv2_block2_0_relu (Activation)
#   Layer 16: conv2_block2_1_conv (Conv2D)
#   Layer 17: conv2_block2_1_bn (BatchNormalization)
#   Layer 18: conv2_block2_1_relu (Activation)
#   Layer 19: conv2_block2_2_conv (Conv2D)
#   Layer 20: conv2_block2_concat (Concatenate)
#   Layer 21: conv2_block3_0_bn (BatchNormalization)
#   Layer 22: conv2_block3_0_relu (Activation)
#   Layer 23: conv2_block3_1_conv (Conv2D)
#   Layer 24: conv2_block3_1_bn (BatchNormalization)
#   Layer 25: conv2_block3_1_relu (Activation)
#   Layer 26: conv2_block3_2_conv (Conv2D)
#   Layer 27: conv2_block3_concat (Concatenate)
#   Layer 28: conv2_block4_0_bn (BatchNormalization)
#   Layer 29: conv2_block4_0_relu (Activation)
#   Layer 30: conv2_block4_1_conv (Conv2D)
#   Layer 31: conv2_block4_1_bn (BatchNormalization)
#   Layer 32: conv2_block4_1_relu (Activation)
#   Layer 33: conv2_block4_2_conv (Conv2D)
#   Layer 34: conv2_block4_concat (Concatenate)
#   Layer 35: conv2_block5_0_bn (BatchNormalization)
#   Layer 36: conv2_block5_0_relu (Activation)
#   Layer 37: conv2_block5_1_conv (Conv2D)
#   Layer 38: conv2_block5_1_bn (BatchNormalization)
#   Layer 39: conv2_block5_1_relu (Activation)
#   Layer 40: conv2_block5_2_conv (Conv2D)
#   Layer 41: conv2_block5_concat (Concatenate)
#   Layer 42: conv2_block6_0_bn (BatchNormalization)
#   Layer 43: conv2_block6_0_relu (Activation)
#   Layer 44: conv2_block6_1_conv (Conv2D)
#   Layer 45: conv2_block6_1_bn (BatchNormalization)
#   Layer 46: conv2_block6_1_relu (Activation)
#   Layer 47: conv2_block6_2_conv (Conv2D)
#   Layer 48: conv2_block6_concat (Concatenate)
#   Layer 49: pool2_bn (BatchNormalization)
#   Layer 50: pool2_relu (Activation)
#   Layer 51: pool2_conv (Conv2D)
#   Layer 52: pool2_pool (AveragePooling2D)
#   Layer 53: conv3_block1_0_bn (BatchNormalization)
#   Layer 54: conv3_block1_0_relu (Activation)
#   Layer 55: conv3_block1_1_conv (Conv2D)
#   Layer 56: conv3_block1_1_bn (BatchNormalization)
#   Layer 57: conv3_block1_1_relu (Activation)
#   Layer 58: conv3_block1_2_conv (Conv2D)
#   Layer 59: conv3_block1_concat (Concatenate)
#   Layer 60: conv3_block2_0_bn (BatchNormalization)
#   Layer 61: conv3_block2_0_relu (Activation)
#   Layer 62: conv3_block2_1_conv (Conv2D)
#   Layer 63: conv3_block2_1_bn (BatchNormalization)
#   Layer 64: conv3_block2_1_relu (Activation)
#   Layer 65: conv3_block2_2_conv (Conv2D)
#   Layer 66: conv3_block2_concat (Concatenate)
#   Layer 67: conv3_block3_0_bn (BatchNormalization)
#   Layer 68: conv3_block3_0_relu (Activation)
#   Layer 69: conv3_block3_1_conv (Conv2D)
#   Layer 70: conv3_block3_1_bn (BatchNormalization)
#   Layer 71: conv3_block3_1_relu (Activation)
#   Layer 72: conv3_block3_2_conv (Conv2D)
#   Layer 73: conv3_block3_concat (Concatenate)
#   Layer 74: conv3_block4_0_bn (BatchNormalization)
#   Layer 75: conv3_block4_0_relu (Activation)
#   Layer 76: conv3_block4_1_conv (Conv2D)
#   Layer 77: conv3_block4_1_bn (BatchNormalization)
#   Layer 78: conv3_block4_1_relu (Activation)
#   Layer 79: conv3_block4_2_conv (Conv2D)
#   Layer 80: conv3_block4_concat (Concatenate)
#   Layer 81: conv3_block5_0_bn (BatchNormalization)
#   Layer 82: conv3_block5_0_relu (Activation)
#   Layer 83: conv3_block5_1_conv (Conv2D)
#   Layer 84: conv3_block5_1_bn (BatchNormalization)
#   Layer 85: conv3_block5_1_relu (Activation)
#   Layer 86: conv3_block5_2_conv (Conv2D)
#   Layer 87: conv3_block5_concat (Concatenate)
#   Layer 88: conv3_block6_0_bn (BatchNormalization)
#   Layer 89: conv3_block6_0_relu (Activation)
#   Layer 90: conv3_block6_1_conv (Conv2D)
#   Layer 91: conv3_block6_1_bn (BatchNormalization)
#   Layer 92: conv3_block6_1_relu (Activation)
#   Layer 93: conv3_block6_2_conv (Conv2D)
#   Layer 94: conv3_block6_concat (Concatenate)
#   Layer 95: conv3_block7_0_bn (BatchNormalization)
#   Layer 96: conv3_block7_0_relu (Activation)
#   Layer 97: conv3_block7_1_conv (Conv2D)
#   Layer 98: conv3_block7_1_bn (BatchNormalization)
#   Layer 99: conv3_block7_1_relu (Activation)
#   Layer 100: conv3_block7_2_conv (Conv2D)
#   Layer 101: conv3_block7_concat (Concatenate)
#   Layer 102: conv3_block8_0_bn (BatchNormalization)
#   Layer 103: conv3_block8_0_relu (Activation)
#   Layer 104: conv3_block8_1_conv (Conv2D)
#   Layer 105: conv3_block8_1_bn (BatchNormalization)
#   Layer 106: conv3_block8_1_relu (Activation)
#   Layer 107: conv3_block8_2_conv (Conv2D)
#   Layer 108: conv3_block8_concat (Concatenate)
#   Layer 109: conv3_block9_0_bn (BatchNormalization)
#   Layer 110: conv3_block9_0_relu (Activation)
#   Layer 111: conv3_block9_1_conv (Conv2D)
#   Layer 112: conv3_block9_1_bn (BatchNormalization)
#   Layer 113: conv3_block9_1_relu (Activation)
#   Layer 114: conv3_block9_2_conv (Conv2D)
#   Layer 115: conv3_block9_concat (Concatenate)
#   Layer 116: conv3_block10_0_bn (BatchNormalization)
#   Layer 117: conv3_block10_0_relu (Activation)
#   Layer 118: conv3_block10_1_conv (Conv2D)
#   Layer 119: conv3_block10_1_bn (BatchNormalization)
#   Layer 120: conv3_block10_1_relu (Activation)
#   Layer 121: conv3_block10_2_conv (Conv2D)
#   Layer 122: conv3_block10_concat (Concatenate)
#   Layer 123: conv3_block11_0_bn (BatchNormalization)
#   Layer 124: conv3_block11_0_relu (Activation)
#   Layer 125: conv3_block11_1_conv (Conv2D)
#   Layer 126: conv3_block11_1_bn (BatchNormalization)
#   Layer 127: conv3_block11_1_relu (Activation)
#   Layer 128: conv3_block11_2_conv (Conv2D)
#   Layer 129: conv3_block11_concat (Concatenate)
#   Layer 130: conv3_block12_0_bn (BatchNormalization)
#   Layer 131: conv3_block12_0_relu (Activation)
#   Layer 132: conv3_block12_1_conv (Conv2D)
#   Layer 133: conv3_block12_1_bn (BatchNormalization)
#   Layer 134: conv3_block12_1_relu (Activation)
#   Layer 135: conv3_block12_2_conv (Conv2D)
#   Layer 136: conv3_block12_concat (Concatenate)
#   Layer 137: pool3_bn (BatchNormalization)
#   Layer 138: pool3_relu (Activation)
#   Layer 139: pool3_conv (Conv2D)
#   Layer 140: pool3_pool (AveragePooling2D)
#   Layer 141: conv4_block1_0_bn (BatchNormalization)
#   Layer 142: conv4_block1_0_relu (Activation)
#   Layer 143: conv4_block1_1_conv (Conv2D)
#   Layer 144: conv4_block1_1_bn (BatchNormalization)
#   Layer 145: conv4_block1_1_relu (Activation)
#   Layer 146: conv4_block1_2_conv (Conv2D)
#   Layer 147: conv4_block1_concat (Concatenate)
#   Layer 148: conv4_block2_0_bn (BatchNormalization)
#   Layer 149: conv4_block2_0_relu (Activation)
#   Layer 150: conv4_block2_1_conv (Conv2D)
#   Layer 151: conv4_block2_1_bn (BatchNormalization)
#   Layer 152: conv4_block2_1_relu (Activation)
#   Layer 153: conv4_block2_2_conv (Conv2D)
#   Layer 154: conv4_block2_concat (Concatenate)
#   Layer 155: conv4_block3_0_bn (BatchNormalization)
#   Layer 156: conv4_block3_0_relu (Activation)
#   Layer 157: conv4_block3_1_conv (Conv2D)
#   Layer 158: conv4_block3_1_bn (BatchNormalization)
#   Layer 159: conv4_block3_1_relu (Activation)
#   Layer 160: conv4_block3_2_conv (Conv2D)
#   Layer 161: conv4_block3_concat (Concatenate)
#   Layer 162: conv4_block4_0_bn (BatchNormalization)
#   Layer 163: conv4_block4_0_relu (Activation)
#   Layer 164: conv4_block4_1_conv (Conv2D)
#   Layer 165: conv4_block4_1_bn (BatchNormalization)
#   Layer 166: conv4_block4_1_relu (Activation)
#   Layer 167: conv4_block4_2_conv (Conv2D)
#   Layer 168: conv4_block4_concat (Concatenate)
#   Layer 169: conv4_block5_0_bn (BatchNormalization)
#   Layer 170: conv4_block5_0_relu (Activation)
#   Layer 171: conv4_block5_1_conv (Conv2D)
#   Layer 172: conv4_block5_1_bn (BatchNormalization)
#   Layer 173: conv4_block5_1_relu (Activation)
#   Layer 174: conv4_block5_2_conv (Conv2D)
#   Layer 175: conv4_block5_concat (Concatenate)
#   Layer 176: conv4_block6_0_bn (BatchNormalization)
#   Layer 177: conv4_block6_0_relu (Activation)
#   Layer 178: conv4_block6_1_conv (Conv2D)
#   Layer 179: conv4_block6_1_bn (BatchNormalization)
#   Layer 180: conv4_block6_1_relu (Activation)
#   Layer 181: conv4_block6_2_conv (Conv2D)
#   Layer 182: conv4_block6_concat (Concatenate)
#   Layer 183: conv4_block7_0_bn (BatchNormalization)
#   Layer 184: conv4_block7_0_relu (Activation)
#   Layer 185: conv4_block7_1_conv (Conv2D)
#   Layer 186: conv4_block7_1_bn (BatchNormalization)
#   Layer 187: conv4_block7_1_relu (Activation)
#   Layer 188: conv4_block7_2_conv (Conv2D)
#   Layer 189: conv4_block7_concat (Concatenate)
#   Layer 190: conv4_block8_0_bn (BatchNormalization)
#   Layer 191: conv4_block8_0_relu (Activation)
#   Layer 192: conv4_block8_1_conv (Conv2D)
#   Layer 193: conv4_block8_1_bn (BatchNormalization)
#   Layer 194: conv4_block8_1_relu (Activation)
#   Layer 195: conv4_block8_2_conv (Conv2D)
#   Layer 196: conv4_block8_concat (Concatenate)
#   Layer 197: conv4_block9_0_bn (BatchNormalization)
#   Layer 198: conv4_block9_0_relu (Activation)
#   Layer 199: conv4_block9_1_conv (Conv2D)
#   Layer 200: conv4_block9_1_bn (BatchNormalization)
#   Layer 201: conv4_block9_1_relu (Activation)
#   Layer 202: conv4_block9_2_conv (Conv2D)
#   Layer 203: conv4_block9_concat (Concatenate)
#   Layer 204: conv4_block10_0_bn (BatchNormalization)
#   Layer 205: conv4_block10_0_relu (Activation)
#   Layer 206: conv4_block10_1_conv (Conv2D)
#   Layer 207: conv4_block10_1_bn (BatchNormalization)
#   Layer 208: conv4_block10_1_relu (Activation)
#   Layer 209: conv4_block10_2_conv (Conv2D)
#   Layer 210: conv4_block10_concat (Concatenate)
#   Layer 211: conv4_block11_0_bn (BatchNormalization)
#   Layer 212: conv4_block11_0_relu (Activation)
#   Layer 213: conv4_block11_1_conv (Conv2D)
#   Layer 214: conv4_block11_1_bn (BatchNormalization)
#   Layer 215: conv4_block11_1_relu (Activation)
#   Layer 216: conv4_block11_2_conv (Conv2D)
#   Layer 217: conv4_block11_concat (Concatenate)
#   Layer 218: conv4_block12_0_bn (BatchNormalization)
#   Layer 219: conv4_block12_0_relu (Activation)
#   Layer 220: conv4_block12_1_conv (Conv2D)
#   Layer 221: conv4_block12_1_bn (BatchNormalization)
#   Layer 222: conv4_block12_1_relu (Activation)
#   Layer 223: conv4_block12_2_conv (Conv2D)
#   Layer 224: conv4_block12_concat (Concatenate)
#   Layer 225: conv4_block13_0_bn (BatchNormalization)
#   Layer 226: conv4_block13_0_relu (Activation)
#   Layer 227: conv4_block13_1_conv (Conv2D)
#   Layer 228: conv4_block13_1_bn (BatchNormalization)
#   Layer 229: conv4_block13_1_relu (Activation)
#   Layer 230: conv4_block13_2_conv (Conv2D)
#   Layer 231: conv4_block13_concat (Concatenate)
#   Layer 232: conv4_block14_0_bn (BatchNormalization)
#   Layer 233: conv4_block14_0_relu (Activation)
#   Layer 234: conv4_block14_1_conv (Conv2D)
#   Layer 235: conv4_block14_1_bn (BatchNormalization)
#   Layer 236: conv4_block14_1_relu (Activation)
#   Layer 237: conv4_block14_2_conv (Conv2D)
#   Layer 238: conv4_block14_concat (Concatenate)
#   Layer 239: conv4_block15_0_bn (BatchNormalization)
#   Layer 240: conv4_block15_0_relu (Activation)
#   Layer 241: conv4_block15_1_conv (Conv2D)
#   Layer 242: conv4_block15_1_bn (BatchNormalization)
#   Layer 243: conv4_block15_1_relu (Activation)
#   Layer 244: conv4_block15_2_conv (Conv2D)
#   Layer 245: conv4_block15_concat (Concatenate)
#   Layer 246: conv4_block16_0_bn (BatchNormalization)
#   Layer 247: conv4_block16_0_relu (Activation)
#   Layer 248: conv4_block16_1_conv (Conv2D)
#   Layer 249: conv4_block16_1_bn (BatchNormalization)
#   Layer 250: conv4_block16_1_relu (Activation)
#   Layer 251: conv4_block16_2_conv (Conv2D)
#   Layer 252: conv4_block16_concat (Concatenate)
#   Layer 253: conv4_block17_0_bn (BatchNormalization)
#   Layer 254: conv4_block17_0_relu (Activation)
#   Layer 255: conv4_block17_1_conv (Conv2D)
#   Layer 256: conv4_block17_1_bn (BatchNormalization)
#   Layer 257: conv4_block17_1_relu (Activation)
#   Layer 258: conv4_block17_2_conv (Conv2D)
#   Layer 259: conv4_block17_concat (Concatenate)
#   Layer 260: conv4_block18_0_bn (BatchNormalization)
#   Layer 261: conv4_block18_0_relu (Activation)
#   Layer 262: conv4_block18_1_conv (Conv2D)
#   Layer 263: conv4_block18_1_bn (BatchNormalization)
#   Layer 264: conv4_block18_1_relu (Activation)
#   Layer 265: conv4_block18_2_conv (Conv2D)
#   Layer 266: conv4_block18_concat (Concatenate)
#   Layer 267: conv4_block19_0_bn (BatchNormalization)
#   Layer 268: conv4_block19_0_relu (Activation)
#   Layer 269: conv4_block19_1_conv (Conv2D)
#   Layer 270: conv4_block19_1_bn (BatchNormalization)
#   Layer 271: conv4_block19_1_relu (Activation)
#   Layer 272: conv4_block19_2_conv (Conv2D)
#   Layer 273: conv4_block19_concat (Concatenate)
#   Layer 274: conv4_block20_0_bn (BatchNormalization)
#   Layer 275: conv4_block20_0_relu (Activation)
#   Layer 276: conv4_block20_1_conv (Conv2D)
#   Layer 277: conv4_block20_1_bn (BatchNormalization)
#   Layer 278: conv4_block20_1_relu (Activation)
#   Layer 279: conv4_block20_2_conv (Conv2D)
#   Layer 280: conv4_block20_concat (Concatenate)
#   Layer 281: conv4_block21_0_bn (BatchNormalization)
#   Layer 282: conv4_block21_0_relu (Activation)
#   Layer 283: conv4_block21_1_conv (Conv2D)
#   Layer 284: conv4_block21_1_bn (BatchNormalization)
#   Layer 285: conv4_block21_1_relu (Activation)
#   Layer 286: conv4_block21_2_conv (Conv2D)
#   Layer 287: conv4_block21_concat (Concatenate)
#   Layer 288: conv4_block22_0_bn (BatchNormalization)
#   Layer 289: conv4_block22_0_relu (Activation)
#   Layer 290: conv4_block22_1_conv (Conv2D)
#   Layer 291: conv4_block22_1_bn (BatchNormalization)
#   Layer 292: conv4_block22_1_relu (Activation)
#   Layer 293: conv4_block22_2_conv (Conv2D)
#   Layer 294: conv4_block22_concat (Concatenate)
#   Layer 295: conv4_block23_0_bn (BatchNormalization)
#   Layer 296: conv4_block23_0_relu (Activation)
#   Layer 297: conv4_block23_1_conv (Conv2D)
#   Layer 298: conv4_block23_1_bn (BatchNormalization)
#   Layer 299: conv4_block23_1_relu (Activation)
#   Layer 300: conv4_block23_2_conv (Conv2D)
#   Layer 301: conv4_block23_concat (Concatenate)
#   Layer 302: conv4_block24_0_bn (BatchNormalization)
#   Layer 303: conv4_block24_0_relu (Activation)
#   Layer 304: conv4_block24_1_conv (Conv2D)
#   Layer 305: conv4_block24_1_bn (BatchNormalization)
#   Layer 306: conv4_block24_1_relu (Activation)
#   Layer 307: conv4_block24_2_conv (Conv2D)
#   Layer 308: conv4_block24_concat (Concatenate)
#   Layer 309: conv4_block25_0_bn (BatchNormalization)
#   Layer 310: conv4_block25_0_relu (Activation)
#   Layer 311: conv4_block25_1_conv (Conv2D)
#   Layer 312: conv4_block25_1_bn (BatchNormalization)
#   Layer 313: conv4_block25_1_relu (Activation)
#   Layer 314: conv4_block25_2_conv (Conv2D)
#   Layer 315: conv4_block25_concat (Concatenate)
#   Layer 316: conv4_block26_0_bn (BatchNormalization)
#   Layer 317: conv4_block26_0_relu (Activation)
#   Layer 318: conv4_block26_1_conv (Conv2D)
#   Layer 319: conv4_block26_1_bn (BatchNormalization)
#   Layer 320: conv4_block26_1_relu (Activation)
#   Layer 321: conv4_block26_2_conv (Conv2D)
#   Layer 322: conv4_block26_concat (Concatenate)
#   Layer 323: conv4_block27_0_bn (BatchNormalization)
#   Layer 324: conv4_block27_0_relu (Activation)
#   Layer 325: conv4_block27_1_conv (Conv2D)
#   Layer 326: conv4_block27_1_bn (BatchNormalization)
#   Layer 327: conv4_block27_1_relu (Activation)
#   Layer 328: conv4_block27_2_conv (Conv2D)
#   Layer 329: conv4_block27_concat (Concatenate)
#   Layer 330: conv4_block28_0_bn (BatchNormalization)
#   Layer 331: conv4_block28_0_relu (Activation)
#   Layer 332: conv4_block28_1_conv (Conv2D)
#   Layer 333: conv4_block28_1_bn (BatchNormalization)
#   Layer 334: conv4_block28_1_relu (Activation)
#   Layer 335: conv4_block28_2_conv (Conv2D)
#   Layer 336: conv4_block28_concat (Concatenate)
#   Layer 337: conv4_block29_0_bn (BatchNormalization)
#   Layer 338: conv4_block29_0_relu (Activation)
#   Layer 339: conv4_block29_1_conv (Conv2D)
#   Layer 340: conv4_block29_1_bn (BatchNormalization)
#   Layer 341: conv4_block29_1_relu (Activation)
#   Layer 342: conv4_block29_2_conv (Conv2D)
#   Layer 343: conv4_block29_concat (Concatenate)
#   Layer 344: conv4_block30_0_bn (BatchNormalization)
#   Layer 345: conv4_block30_0_relu (Activation)
#   Layer 346: conv4_block30_1_conv (Conv2D)
#   Layer 347: conv4_block30_1_bn (BatchNormalization)
#   Layer 348: conv4_block30_1_relu (Activation)
#   Layer 349: conv4_block30_2_conv (Conv2D)
#   Layer 350: conv4_block30_concat (Concatenate)
#   Layer 351: conv4_block31_0_bn (BatchNormalization)
#   Layer 352: conv4_block31_0_relu (Activation)
#   Layer 353: conv4_block31_1_conv (Conv2D)
#   Layer 354: conv4_block31_1_bn (BatchNormalization)
#   Layer 355: conv4_block31_1_relu (Activation)
#   Layer 356: conv4_block31_2_conv (Conv2D)
#   Layer 357: conv4_block31_concat (Concatenate)
#   Layer 358: conv4_block32_0_bn (BatchNormalization)
#   Layer 359: conv4_block32_0_relu (Activation)
#   Layer 360: conv4_block32_1_conv (Conv2D)
#   Layer 361: conv4_block32_1_bn (BatchNormalization)
#   Layer 362: conv4_block32_1_relu (Activation)
#   Layer 363: conv4_block32_2_conv (Conv2D)
#   Layer 364: conv4_block32_concat (Concatenate)
#   Layer 365: conv4_block33_0_bn (BatchNormalization)
#   Layer 366: conv4_block33_0_relu (Activation)
#   Layer 367: conv4_block33_1_conv (Conv2D)
#   Layer 368: conv4_block33_1_bn (BatchNormalization)
#   Layer 369: conv4_block33_1_relu (Activation)
#   Layer 370: conv4_block33_2_conv (Conv2D)
#   Layer 371: conv4_block33_concat (Concatenate)
#   Layer 372: conv4_block34_0_bn (BatchNormalization)
#   Layer 373: conv4_block34_0_relu (Activation)
#   Layer 374: conv4_block34_1_conv (Conv2D)
#   Layer 375: conv4_block34_1_bn (BatchNormalization)
#   Layer 376: conv4_block34_1_relu (Activation)
#   Layer 377: conv4_block34_2_conv (Conv2D)
#   Layer 378: conv4_block34_concat (Concatenate)
#   Layer 379: conv4_block35_0_bn (BatchNormalization)
#   Layer 380: conv4_block35_0_relu (Activation)
#   Layer 381: conv4_block35_1_conv (Conv2D)
#   Layer 382: conv4_block35_1_bn (BatchNormalization)
#   Layer 383: conv4_block35_1_relu (Activation)
#   Layer 384: conv4_block35_2_conv (Conv2D)
#   Layer 385: conv4_block35_concat (Concatenate)
#   Layer 386: conv4_block36_0_bn (BatchNormalization)
#   Layer 387: conv4_block36_0_relu (Activation)
#   Layer 388: conv4_block36_1_conv (Conv2D)
#   Layer 389: conv4_block36_1_bn (BatchNormalization)
#   Layer 390: conv4_block36_1_relu (Activation)
#   Layer 391: conv4_block36_2_conv (Conv2D)
#   Layer 392: conv4_block36_concat (Concatenate)
#   Layer 393: conv4_block37_0_bn (BatchNormalization)
#   Layer 394: conv4_block37_0_relu (Activation)
#   Layer 395: conv4_block37_1_conv (Conv2D)
#   Layer 396: conv4_block37_1_bn (BatchNormalization)
#   Layer 397: conv4_block37_1_relu (Activation)
#   Layer 398: conv4_block37_2_conv (Conv2D)
#   Layer 399: conv4_block37_concat (Concatenate)
#   Layer 400: conv4_block38_0_bn (BatchNormalization)
#   Layer 401: conv4_block38_0_relu (Activation)
#   Layer 402: conv4_block38_1_conv (Conv2D)
#   Layer 403: conv4_block38_1_bn (BatchNormalization)
#   Layer 404: conv4_block38_1_relu (Activation)
#   Layer 405: conv4_block38_2_conv (Conv2D)
#   Layer 406: conv4_block38_concat (Concatenate)
#   Layer 407: conv4_block39_0_bn (BatchNormalization)
#   Layer 408: conv4_block39_0_relu (Activation)
#   Layer 409: conv4_block39_1_conv (Conv2D)
#   Layer 410: conv4_block39_1_bn (BatchNormalization)
#   Layer 411: conv4_block39_1_relu (Activation)
#   Layer 412: conv4_block39_2_conv (Conv2D)
#   Layer 413: conv4_block39_concat (Concatenate)
#   Layer 414: conv4_block40_0_bn (BatchNormalization)
#   Layer 415: conv4_block40_0_relu (Activation)
#   Layer 416: conv4_block40_1_conv (Conv2D)
#   Layer 417: conv4_block40_1_bn (BatchNormalization)
#   Layer 418: conv4_block40_1_relu (Activation)
#   Layer 419: conv4_block40_2_conv (Conv2D)
#   Layer 420: conv4_block40_concat (Concatenate)
#   Layer 421: conv4_block41_0_bn (BatchNormalization)
#   Layer 422: conv4_block41_0_relu (Activation)
#   Layer 423: conv4_block41_1_conv (Conv2D)
#   Layer 424: conv4_block41_1_bn (BatchNormalization)
#   Layer 425: conv4_block41_1_relu (Activation)
#   Layer 426: conv4_block41_2_conv (Conv2D)
#   Layer 427: conv4_block41_concat (Concatenate)
#   Layer 428: conv4_block42_0_bn (BatchNormalization)
#   Layer 429: conv4_block42_0_relu (Activation)
#   Layer 430: conv4_block42_1_conv (Conv2D)
#   Layer 431: conv4_block42_1_bn (BatchNormalization)
#   Layer 432: conv4_block42_1_relu (Activation)
#   Layer 433: conv4_block42_2_conv (Conv2D)
#   Layer 434: conv4_block42_concat (Concatenate)
#   Layer 435: conv4_block43_0_bn (BatchNormalization)
#   Layer 436: conv4_block43_0_relu (Activation)
#   Layer 437: conv4_block43_1_conv (Conv2D)
#   Layer 438: conv4_block43_1_bn (BatchNormalization)
#   Layer 439: conv4_block43_1_relu (Activation)
#   Layer 440: conv4_block43_2_conv (Conv2D)
#   Layer 441: conv4_block43_concat (Concatenate)
#   Layer 442: conv4_block44_0_bn (BatchNormalization)
#   Layer 443: conv4_block44_0_relu (Activation)
#   Layer 444: conv4_block44_1_conv (Conv2D)
#   Layer 445: conv4_block44_1_bn (BatchNormalization)
#   Layer 446: conv4_block44_1_relu (Activation)
#   Layer 447: conv4_block44_2_conv (Conv2D)
#   Layer 448: conv4_block44_concat (Concatenate)
#   Layer 449: conv4_block45_0_bn (BatchNormalization)
#   Layer 450: conv4_block45_0_relu (Activation)
#   Layer 451: conv4_block45_1_conv (Conv2D)
#   Layer 452: conv4_block45_1_bn (BatchNormalization)
#   Layer 453: conv4_block45_1_relu (Activation)
#   Layer 454: conv4_block45_2_conv (Conv2D)
#   Layer 455: conv4_block45_concat (Concatenate)
#   Layer 456: conv4_block46_0_bn (BatchNormalization)
#   Layer 457: conv4_block46_0_relu (Activation)
#   Layer 458: conv4_block46_1_conv (Conv2D)
#   Layer 459: conv4_block46_1_bn (BatchNormalization)
#   Layer 460: conv4_block46_1_relu (Activation)
#   Layer 461: conv4_block46_2_conv (Conv2D)
#   Layer 462: conv4_block46_concat (Concatenate)
#   Layer 463: conv4_block47_0_bn (BatchNormalization)
#   Layer 464: conv4_block47_0_relu (Activation)
#   Layer 465: conv4_block47_1_conv (Conv2D)
#   Layer 466: conv4_block47_1_bn (BatchNormalization)
#   Layer 467: conv4_block47_1_relu (Activation)
#   Layer 468: conv4_block47_2_conv (Conv2D)
#   Layer 469: conv4_block47_concat (Concatenate)
#   Layer 470: conv4_block48_0_bn (BatchNormalization)
#   Layer 471: conv4_block48_0_relu (Activation)
#   Layer 472: conv4_block48_1_conv (Conv2D)
#   Layer 473: conv4_block48_1_bn (BatchNormalization)
#   Layer 474: conv4_block48_1_relu (Activation)
#   Layer 475: conv4_block48_2_conv (Conv2D)
#   Layer 476: conv4_block48_concat (Concatenate)
#   Layer 477: pool4_bn (BatchNormalization)
#   Layer 478: pool4_relu (Activation)
#   Layer 479: pool4_conv (Conv2D)
#   Layer 480: pool4_pool (AveragePooling2D)
#   Layer 481: conv5_block1_0_bn (BatchNormalization)
#   Layer 482: conv5_block1_0_relu (Activation)
#   Layer 483: conv5_block1_1_conv (Conv2D)
#   Layer 484: conv5_block1_1_bn (BatchNormalization)
#   Layer 485: conv5_block1_1_relu (Activation)
#   Layer 486: conv5_block1_2_conv (Conv2D)
#   Layer 487: conv5_block1_concat (Concatenate)
#   Layer 488: conv5_block2_0_bn (BatchNormalization)
#   Layer 489: conv5_block2_0_relu (Activation)
#   Layer 490: conv5_block2_1_conv (Conv2D)
#   Layer 491: conv5_block2_1_bn (BatchNormalization)
#   Layer 492: conv5_block2_1_relu (Activation)
#   Layer 493: conv5_block2_2_conv (Conv2D)
#   Layer 494: conv5_block2_concat (Concatenate)
#   Layer 495: conv5_block3_0_bn (BatchNormalization)
#   Layer 496: conv5_block3_0_relu (Activation)
#   Layer 497: conv5_block3_1_conv (Conv2D)
#   Layer 498: conv5_block3_1_bn (BatchNormalization)
#   Layer 499: conv5_block3_1_relu (Activation)
#   Layer 500: conv5_block3_2_conv (Conv2D)
#   Layer 501: conv5_block3_concat (Concatenate)
#   Layer 502: conv5_block4_0_bn (BatchNormalization)
#   Layer 503: conv5_block4_0_relu (Activation)
#   Layer 504: conv5_block4_1_conv (Conv2D)
#   Layer 505: conv5_block4_1_bn (BatchNormalization)
#   Layer 506: conv5_block4_1_relu (Activation)
#   Layer 507: conv5_block4_2_conv (Conv2D)
#   Layer 508: conv5_block4_concat (Concatenate)
#   Layer 509: conv5_block5_0_bn (BatchNormalization)
#   Layer 510: conv5_block5_0_relu (Activation)
#   Layer 511: conv5_block5_1_conv (Conv2D)
#   Layer 512: conv5_block5_1_bn (BatchNormalization)
#   Layer 513: conv5_block5_1_relu (Activation)
#   Layer 514: conv5_block5_2_conv (Conv2D)
#   Layer 515: conv5_block5_concat (Concatenate)
#   Layer 516: conv5_block6_0_bn (BatchNormalization)
#   Layer 517: conv5_block6_0_relu (Activation)
#   Layer 518: conv5_block6_1_conv (Conv2D)
#   Layer 519: conv5_block6_1_bn (BatchNormalization)
#   Layer 520: conv5_block6_1_relu (Activation)
#   Layer 521: conv5_block6_2_conv (Conv2D)
#   Layer 522: conv5_block6_concat (Concatenate)
#   Layer 523: conv5_block7_0_bn (BatchNormalization)
#   Layer 524: conv5_block7_0_relu (Activation)
#   Layer 525: conv5_block7_1_conv (Conv2D)
#   Layer 526: conv5_block7_1_bn (BatchNormalization)
#   Layer 527: conv5_block7_1_relu (Activation)
#   Layer 528: conv5_block7_2_conv (Conv2D)
#   Layer 529: conv5_block7_concat (Concatenate)
#   Layer 530: conv5_block8_0_bn (BatchNormalization)
#   Layer 531: conv5_block8_0_relu (Activation)
#   Layer 532: conv5_block8_1_conv (Conv2D)
#   Layer 533: conv5_block8_1_bn (BatchNormalization)
#   Layer 534: conv5_block8_1_relu (Activation)
#   Layer 535: conv5_block8_2_conv (Conv2D)
#   Layer 536: conv5_block8_concat (Concatenate)
#   Layer 537: conv5_block9_0_bn (BatchNormalization)
#   Layer 538: conv5_block9_0_relu (Activation)
#   Layer 539: conv5_block9_1_conv (Conv2D)
#   Layer 540: conv5_block9_1_bn (BatchNormalization)
#   Layer 541: conv5_block9_1_relu (Activation)
#   Layer 542: conv5_block9_2_conv (Conv2D)
#   Layer 543: conv5_block9_concat (Concatenate)
#   Layer 544: conv5_block10_0_bn (BatchNormalization)
#   Layer 545: conv5_block10_0_relu (Activation)
#   Layer 546: conv5_block10_1_conv (Conv2D)
#   Layer 547: conv5_block10_1_bn (BatchNormalization)
#   Layer 548: conv5_block10_1_relu (Activation)
#   Layer 549: conv5_block10_2_conv (Conv2D)
#   Layer 550: conv5_block10_concat (Concatenate)
#   Layer 551: conv5_block11_0_bn (BatchNormalization)
#   Layer 552: conv5_block11_0_relu (Activation)
#   Layer 553: conv5_block11_1_conv (Conv2D)
#   Layer 554: conv5_block11_1_bn (BatchNormalization)
#   Layer 555: conv5_block11_1_relu (Activation)
#   Layer 556: conv5_block11_2_conv (Conv2D)
#   Layer 557: conv5_block11_concat (Concatenate)
#   Layer 558: conv5_block12_0_bn (BatchNormalization)
#   Layer 559: conv5_block12_0_relu (Activation)
#   Layer 560: conv5_block12_1_conv (Conv2D)
#   Layer 561: conv5_block12_1_bn (BatchNormalization)
#   Layer 562: conv5_block12_1_relu (Activation)
#   Layer 563: conv5_block12_2_conv (Conv2D)
#   Layer 564: conv5_block12_concat (Concatenate)
#   Layer 565: conv5_block13_0_bn (BatchNormalization)
#   Layer 566: conv5_block13_0_relu (Activation)
#   Layer 567: conv5_block13_1_conv (Conv2D)
#   Layer 568: conv5_block13_1_bn (BatchNormalization)
#   Layer 569: conv5_block13_1_relu (Activation)
#   Layer 570: conv5_block13_2_conv (Conv2D)
#   Layer 571: conv5_block13_concat (Concatenate)
#   Layer 572: conv5_block14_0_bn (BatchNormalization)
#   Layer 573: conv5_block14_0_relu (Activation)
#   Layer 574: conv5_block14_1_conv (Conv2D)
#   Layer 575: conv5_block14_1_bn (BatchNormalization)
#   Layer 576: conv5_block14_1_relu (Activation)
#   Layer 577: conv5_block14_2_conv (Conv2D)
#   Layer 578: conv5_block14_concat (Concatenate)
#   Layer 579: conv5_block15_0_bn (BatchNormalization)
#   Layer 580: conv5_block15_0_relu (Activation)
#   Layer 581: conv5_block15_1_conv (Conv2D)
#   Layer 582: conv5_block15_1_bn (BatchNormalization)
#   Layer 583: conv5_block15_1_relu (Activation)
#   Layer 584: conv5_block15_2_conv (Conv2D)
#   Layer 585: conv5_block15_concat (Concatenate)
#   Layer 586: conv5_block16_0_bn (BatchNormalization)
#   Layer 587: conv5_block16_0_relu (Activation)
#   Layer 588: conv5_block16_1_conv (Conv2D)
#   Layer 589: conv5_block16_1_bn (BatchNormalization)
#   Layer 590: conv5_block16_1_relu (Activation)
#   Layer 591: conv5_block16_2_conv (Conv2D)
#   Layer 592: conv5_block16_concat (Concatenate)
#   Layer 593: conv5_block17_0_bn (BatchNormalization)
#   Layer 594: conv5_block17_0_relu (Activation)
#   Layer 595: conv5_block17_1_conv (Conv2D)
#   Layer 596: conv5_block17_1_bn (BatchNormalization)
#   Layer 597: conv5_block17_1_relu (Activation)
#   Layer 598: conv5_block17_2_conv (Conv2D)
#   Layer 599: conv5_block17_concat (Concatenate)
#   Layer 600: conv5_block18_0_bn (BatchNormalization)
#   Layer 601: conv5_block18_0_relu (Activation)
#   Layer 602: conv5_block18_1_conv (Conv2D)
#   Layer 603: conv5_block18_1_bn (BatchNormalization)
#   Layer 604: conv5_block18_1_relu (Activation)
#   Layer 605: conv5_block18_2_conv (Conv2D)
#   Layer 606: conv5_block18_concat (Concatenate)
#   Layer 607: conv5_block19_0_bn (BatchNormalization)
#   Layer 608: conv5_block19_0_relu (Activation)
#   Layer 609: conv5_block19_1_conv (Conv2D)
#   Layer 610: conv5_block19_1_bn (BatchNormalization)
#   Layer 611: conv5_block19_1_relu (Activation)
#   Layer 612: conv5_block19_2_conv (Conv2D)
#   Layer 613: conv5_block19_concat (Concatenate)
#   Layer 614: conv5_block20_0_bn (BatchNormalization)
#   Layer 615: conv5_block20_0_relu (Activation)
#   Layer 616: conv5_block20_1_conv (Conv2D)
#   Layer 617: conv5_block20_1_bn (BatchNormalization)
#   Layer 618: conv5_block20_1_relu (Activation)
#   Layer 619: conv5_block20_2_conv (Conv2D)
#   Layer 620: conv5_block20_concat (Concatenate)
#   Layer 621: conv5_block21_0_bn (BatchNormalization)
#   Layer 622: conv5_block21_0_relu (Activation)
#   Layer 623: conv5_block21_1_conv (Conv2D)
#   Layer 624: conv5_block21_1_bn (BatchNormalization)
#   Layer 625: conv5_block21_1_relu (Activation)
#   Layer 626: conv5_block21_2_conv (Conv2D)
#   Layer 627: conv5_block21_concat (Concatenate)
#   Layer 628: conv5_block22_0_bn (BatchNormalization)
#   Layer 629: conv5_block22_0_relu (Activation)
#   Layer 630: conv5_block22_1_conv (Conv2D)
#   Layer 631: conv5_block22_1_bn (BatchNormalization)
#   Layer 632: conv5_block22_1_relu (Activation)
#   Layer 633: conv5_block22_2_conv (Conv2D)
#   Layer 634: conv5_block22_concat (Concatenate)
#   Layer 635: conv5_block23_0_bn (BatchNormalization)
#   Layer 636: conv5_block23_0_relu (Activation)
#   Layer 637: conv5_block23_1_conv (Conv2D)
#   Layer 638: conv5_block23_1_bn (BatchNormalization)
#   Layer 639: conv5_block23_1_relu (Activation)
#   Layer 640: conv5_block23_2_conv (Conv2D)
#   Layer 641: conv5_block23_concat (Concatenate)
#   Layer 642: conv5_block24_0_bn (BatchNormalization)
#   Layer 643: conv5_block24_0_relu (Activation)
#   Layer 644: conv5_block24_1_conv (Conv2D)
#   Layer 645: conv5_block24_1_bn (BatchNormalization)
#   Layer 646: conv5_block24_1_relu (Activation)
#   Layer 647: conv5_block24_2_conv (Conv2D)
#   Layer 648: conv5_block24_concat (Concatenate)
#   Layer 649: conv5_block25_0_bn (BatchNormalization)
#   Layer 650: conv5_block25_0_relu (Activation)
#   Layer 651: conv5_block25_1_conv (Conv2D)
#   Layer 652: conv5_block25_1_bn (BatchNormalization)
#   Layer 653: conv5_block25_1_relu (Activation)
#   Layer 654: conv5_block25_2_conv (Conv2D)
#   Layer 655: conv5_block25_concat (Concatenate)
#   Layer 656: conv5_block26_0_bn (BatchNormalization)
#   Layer 657: conv5_block26_0_relu (Activation)
#   Layer 658: conv5_block26_1_conv (Conv2D)
#   Layer 659: conv5_block26_1_bn (BatchNormalization)
#   Layer 660: conv5_block26_1_relu (Activation)
#   Layer 661: conv5_block26_2_conv (Conv2D)
#   Layer 662: conv5_block26_concat (Concatenate)
#   Layer 663: conv5_block27_0_bn (BatchNormalization)
#   Layer 664: conv5_block27_0_relu (Activation)
#   Layer 665: conv5_block27_1_conv (Conv2D)
#   Layer 666: conv5_block27_1_bn (BatchNormalization)
#   Layer 667: conv5_block27_1_relu (Activation)
#   Layer 668: conv5_block27_2_conv (Conv2D)
#   Layer 669: conv5_block27_concat (Concatenate)
#   Layer 670: conv5_block28_0_bn (BatchNormalization)
#   Layer 671: conv5_block28_0_relu (Activation)
#   Layer 672: conv5_block28_1_conv (Conv2D)
#   Layer 673: conv5_block28_1_bn (BatchNormalization)
#   Layer 674: conv5_block28_1_relu (Activation)
#   Layer 675: conv5_block28_2_conv (Conv2D)
#   Layer 676: conv5_block28_concat (Concatenate)
#   Layer 677: conv5_block29_0_bn (BatchNormalization)
#   Layer 678: conv5_block29_0_relu (Activation)
#   Layer 679: conv5_block29_1_conv (Conv2D)
#   Layer 680: conv5_block29_1_bn (BatchNormalization)
#   Layer 681: conv5_block29_1_relu (Activation)
#   Layer 682: conv5_block29_2_conv (Conv2D)
#   Layer 683: conv5_block29_concat (Concatenate)
#   Layer 684: conv5_block30_0_bn (BatchNormalization)
#   Layer 685: conv5_block30_0_relu (Activation)
#   Layer 686: conv5_block30_1_conv (Conv2D)
#   Layer 687: conv5_block30_1_bn (BatchNormalization)
#   Layer 688: conv5_block30_1_relu (Activation)
#   Layer 689: conv5_block30_2_conv (Conv2D)
#   Layer 690: conv5_block30_concat (Concatenate)
#   Layer 691: conv5_block31_0_bn (BatchNormalization)
#   Layer 692: conv5_block31_0_relu (Activation)
#   Layer 693: conv5_block31_1_conv (Conv2D)
#   Layer 694: conv5_block31_1_bn (BatchNormalization)
#   Layer 695: conv5_block31_1_relu (Activation)
#   Layer 696: conv5_block31_2_conv (Conv2D)
#   Layer 697: conv5_block31_concat (Concatenate)
#   Layer 698: conv5_block32_0_bn (BatchNormalization)
#   Layer 699: conv5_block32_0_relu (Activation)
#   Layer 700: conv5_block32_1_conv (Conv2D)
#   Layer 701: conv5_block32_1_bn (BatchNormalization)
#   Layer 702: conv5_block32_1_relu (Activation)
#   Layer 703: conv5_block32_2_conv (Conv2D)
#   Layer 704: conv5_block32_concat (Concatenate)
#   Layer 705: bn (BatchNormalization)
#   Layer 706: relu (Activation)
#   Layer 707: avg_pool (GlobalAveragePooling2D)
#   Layer 708: flatten (Flatten)
#   Layer 709: dense (Dense)
# ============================================================

# %%
# Stage 2: Fine-tuning with progressive layer unfreezing
print("STAGE 2: FINE-TUNING - Unfreezing top DenseNet layers")

# Based on the diagnostic, we know the structure:
# Layers 0-707: DenseNet201 backbone (flattened into main model)
# Layer 708: Flatten layer we added
# Layer 709: Dense classification layer we added

total_layers = len(model.layers)
print(f"Total model layers: {total_layers}")

# Identify the layers
densenet_end_layer = 707  # avg_pool layer
flatten_layer = 708       # Our flatten layer
dense_layer = 709         # Our classification layer

print(f"DenseNet backbone: layers 0-{densenet_end_layer} ({densenet_end_layer + 1} layers)")
print(f"Our additions: Flatten (layer {flatten_layer}), Dense (layer {dense_layer})")

# Configure fine-tuning
UNFREEZE_LAST_N = 30  # Number of top DenseNet layers to unfreeze
densenet_layers_count = densenet_end_layer + 1
unfreeze_from_index = max(0, densenet_layers_count - UNFREEZE_LAST_N)

print(f"\nFine-tuning strategy:")
print(f"  - DenseNet backbone has {densenet_layers_count} layers (0 to {densenet_end_layer})")
print(f"  - Will unfreeze last {UNFREEZE_LAST_N} layers")
print(f"  - Unfreezing from layer {unfreeze_from_index} to {densenet_end_layer}")

# Step 1: Freeze ALL layers first
for layer in model.layers:
    layer.trainable = False

print("  - All layers frozen")

# Step 2: Unfreeze the top N DenseNet layers
unfrozen_count = 0
for i in range(unfreeze_from_index, densenet_layers_count):
    model.layers[i].trainable = True
    unfrozen_count += 1

print(f"  - Unfrozen {unfrozen_count} DenseNet layers (indices {unfreeze_from_index} to {densenet_end_layer})")

# Step 3: Ensure our classifier layers remain trainable
model.layers[flatten_layer].trainable = True  # Flatten layer
model.layers[dense_layer].trainable = True    # Dense classification layer

print(f"  - Classifier layers kept trainable: Flatten (layer {flatten_layer}), Dense (layer {dense_layer})")

# Verify configuration
trainable_backbone = sum(1 for i in range(densenet_layers_count) if model.layers[i].trainable)
trainable_classifier = sum(1 for i in [flatten_layer, dense_layer] if model.layers[i].trainable)
total_trainable = sum(1 for layer in model.layers if layer.trainable)

print(f"\nVerification:")
print(f"  - Trainable DenseNet layers: {trainable_backbone}/{densenet_layers_count}")
print(f"  - Trainable classifier layers: {trainable_classifier}/2")
print(f"  - Total trainable layers: {total_trainable}/{total_layers}")

# Show which layers we're training (last few for verification)
print(f"\nLayers being fine-tuned (last 5 DenseNet + classifier):")
for i in range(max(0, densenet_end_layer - 4), total_layers):
    trainable_status = "TRAINABLE" if model.layers[i].trainable else "FROZEN"
    print(f"  Layer {i}: {model.layers[i].name} ({model.layers[i].__class__.__name__}) - {trainable_status}")

# Recompile with fine-tuning learning rate
fine_tune_lr = 1e-5  # Conservative learning rate for fine-tuning
print(f"\nRecompiling model with learning rate: {fine_tune_lr}")

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_lr),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Show parameter counts
total_trainable_params = sum(tf.keras.backend.count_params(w) for w in model.trainable_weights)
total_non_trainable_params = sum(tf.keras.backend.count_params(w) for w in model.non_trainable_weights)

print(f"\nParameter summary:")
print(f"  - Trainable parameters: {total_trainable_params:,}")
print(f"  - Non-trainable parameters: {total_non_trainable_params:,}")
print(f"  - Total parameters: {(total_trainable_params + total_non_trainable_params):,}")

# Prepare callbacks for fine-tuning
fine_tune_callbacks = [
    EarlyStopping(
        patience=7, 
        restore_best_weights=True, 
        monitor='val_accuracy', 
        mode='max', 
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        mode='max',
        verbose=1
    )
]

# Training parameters
additional_epochs = 15
initial_epochs = len(history.history['loss'])
total_epochs = initial_epochs + additional_epochs

print(f"\nStarting fine-tuning:")
print(f"  - Initial epochs completed: {initial_epochs}")
print(f"  - Additional epochs: {additional_epochs}")
print(f"  - Total epochs target: {total_epochs}")

# Start fine-tuning
print("\nSTARTING FINE-TUNING TRAINING...")

history_fine = model.fit(
    train_ds,
    epochs=total_epochs,
    initial_epoch=initial_epochs,
    validation_data=valid_ds,
    callbacks=fine_tune_callbacks,
    verbose=1
)

print("\nFine-tuning completed successfully!")

# Merge training histories for complete visualization
total_history = {}
for key in history.history.keys():
    total_history[key] = history.history[key] + history_fine.history[key]

print(f"Combined training history: {len(total_history['loss'])} total epochs")

# %%
# Save the final fine-tuned model
fine_tuned_model_path = results_path + '_FineTuned_Enhanced.keras'
model.save(fine_tuned_model_path)
print(f"Fine-tuned model saved to: {fine_tuned_model_path}")

# Also save the original model path for compatibility
model.save(model_path)
print(f"Model also saved to: {model_path}")
# Out:
# Fine-tuned model saved to: D:\MyPaper\Codes\Results\DenseNet201/DenseNet201/_UltraFineTuned_Enhanced.keras
# Model also saved to: D:\MyPaper\Codes\Results\DenseNet201/DenseNet201/_10Epochs.keras
# Model also saved to: D:\MyPaper\Codes\Results\DenseNet201/DenseNet201/_10Epochs.keras

# %%
# Stage 3: Ultra fine-tuning for maximum performance
print("STAGE 3: ULTRA FINE-TUNING - Progressive unfreezing for maximum performance")

# Current status check
current_epochs = len(total_history['loss']) if 'total_history' in locals() else len(history.history['loss'])
current_val_acc = max(total_history['val_accuracy']) if 'total_history' in locals() else max(history.history['val_accuracy'])

print(f"Current training status:")
print(f"  - Completed epochs: {current_epochs}")
print(f"  - Best validation accuracy: {current_val_acc:.4f}")

# Stage 3: Progressive unfreezing - unfreeze MORE layers
print(f"\nStage 3 Strategy: Progressive Layer Unfreezing")
print(f"  - Previous Stage 2: Last 30 layers unfrozen (layers 678-707)")
print(f"  - Stage 3: Unfreezing last 50 layers for deeper fine-tuning")

# Reset all layers to frozen first
for layer in model.layers:
    layer.trainable = False

# Progressive unfreezing: Unfreeze last 50 DenseNet layers instead of 30
UNFREEZE_LAST_N_STAGE3 = 50  # More aggressive unfreezing
densenet_layers_count = 708  # layers 0-707 
unfreeze_from_index = max(0, densenet_layers_count - UNFREEZE_LAST_N_STAGE3)

print(f"  - Unfreezing layers {unfreeze_from_index} to {densenet_layers_count-1} (last {UNFREEZE_LAST_N_STAGE3} layers)")

# Unfreeze the expanded range
for i in range(unfreeze_from_index, densenet_layers_count):
    model.layers[i].trainable = True

# Keep classifier trainable
model.layers[708].trainable = True  # Flatten
model.layers[709].trainable = True  # Dense

# Ultra-conservative learning rate for Stage 3
ultra_fine_lr = 5e-6  # Even lower than Stage 2's 1e-5
print(f"  - Ultra-fine learning rate: {ultra_fine_lr}")

# Recompile with ultra-fine learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=ultra_fine_lr),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Advanced callbacks for Stage 3
stage3_callbacks = [
    EarlyStopping(
        patience=8,  # More patience for ultra-fine tuning
        restore_best_weights=True, 
        monitor='val_accuracy', 
        mode='max', 
        verbose=1,
        min_delta=0.0001  # Very small improvement threshold
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.3,  # More aggressive LR reduction
        patience=3,
        min_lr=1e-7,  # Lower minimum LR
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=results_path + '_Stage3_Best.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

# Training parameters for Stage 3
stage3_epochs = 5  # Conservative additional epochs
current_total_epochs = current_epochs + stage3_epochs

print(f"\nStage 3 Training Plan:")
print(f"  - Additional epochs: {stage3_epochs}")
print(f"  - Target total epochs: {current_total_epochs}")
print(f"  - Trainable layers: {sum(1 for layer in model.layers if layer.trainable)}")

# Parameter summary
trainable_params = sum(tf.keras.backend.count_params(w) for w in model.trainable_weights)
non_trainable_params = sum(tf.keras.backend.count_params(w) for w in model.non_trainable_weights)

print(f"\nStage 3 Parameter Summary:")
print(f"  - Trainable parameters: {trainable_params:,}")
print(f"  - Non-trainable parameters: {non_trainable_params:,}")
print(f"  - Total parameters: {(trainable_params + non_trainable_params):,}")

print("\nSTARTING STAGE 3 ULTRA FINE-TUNING...")

# Execute Stage 3 training
history_stage3 = model.fit(
    train_ds,
    epochs=current_total_epochs,
    initial_epoch=current_epochs,
    validation_data=valid_ds,
    callbacks=stage3_callbacks,
    verbose=1
)

print("\nStage 3 Ultra Fine-tuning completed!")

# Update complete training history
if 'total_history' in locals():
    # Merge all three stages
    complete_history = {}
    for key in total_history.keys():
        complete_history[key] = total_history[key] + history_stage3.history[key]
else:
    # Merge Stage 1 and Stage 3 (if Stage 2 history not available)
    complete_history = {}
    for key in history.history.keys():
        complete_history[key] = history.history[key] + history_stage3.history[key]

print(f"Complete training history: {len(complete_history['loss'])} total epochs")

# Update the total_history for plotting
total_history = complete_history

# %%
# Test Time Augmentation for maximum accuracy
print("TEST TIME AUGMENTATION - Multiple predictions per image for maximum accuracy")

def create_tta_generators(test_directory, target_size, batch_size=32):
    """
    Creates multiple augmented test generators for TTA
    """
    # Base generator (no augmentation)
    base_gen = ImageDataGenerator(preprocessing_function=kidney_preprocessing_pipeline)
    
    # Augmentation generators for TTA
    # Generator 1: Horizontal flip
    gen1 = ImageDataGenerator(
        horizontal_flip=True,
        preprocessing_function=kidney_preprocessing_pipeline
    )
    
    # Generator 2: Small rotation
    gen2 = ImageDataGenerator(
        rotation_range=5,
        preprocessing_function=kidney_preprocessing_pipeline
    )
    
    # Generator 3: Small zoom
    gen3 = ImageDataGenerator(
        zoom_range=0.05,
        preprocessing_function=kidney_preprocessing_pipeline
    )
    
    # Generator 4: Small shift
    gen4 = ImageDataGenerator(
        width_shift_range=0.05,
        height_shift_range=0.05,
        preprocessing_function=kidney_preprocessing_pipeline
    )
    
    generators = [base_gen, gen1, gen2, gen3, gen4]
    
    # Create flow_from_directory for each generator
    tta_datasets = []
    for i, gen in enumerate(generators):
        dataset = gen.flow_from_directory(
            test_directory,
            target_size=target_size,
            batch_size=batch_size,
            class_mode='sparse',
            shuffle=False,  # IMPORTANT: don't shuffle for TTA
            seed=42  # Consistent ordering
        )
        tta_datasets.append(dataset)
        print(f"  - TTA Generator {i+1}: configured")
    
    return tta_datasets

def predict_with_tta(model, tta_datasets, verbose=True):
    """
    Performs Test Time Augmentation prediction
    """
    if verbose:
        print(f"\nPerforming TTA with {len(tta_datasets)} augmentations...")
    
    all_predictions = []
    
    for i, dataset in enumerate(tta_datasets):
        if verbose:
            print(f"  - Running prediction with augmentation {i+1}...")
        
        # Reset dataset to beginning
        dataset.reset()
        
        # Get predictions
        preds = model.predict(dataset, verbose=0)
        all_predictions.append(preds)
        
        if verbose:
            confidence = np.max(preds, axis=1).mean()
            print(f"    Average confidence: {confidence:.4f}")
    
    # Ensemble predictions (average)
    if verbose:
        print(f"  - Averaging predictions from {len(all_predictions)} augmentations...")
    
    ensemble_predictions = np.mean(all_predictions, axis=0)
    
    if verbose:
        final_confidence = np.max(ensemble_predictions, axis=1).mean()
        print(f"  - Final ensemble confidence: {final_confidence:.4f}")
    
    return ensemble_predictions, all_predictions

# Create TTA datasets
print("Creating Test Time Augmentation datasets...")
tta_test_datasets = create_tta_generators(test_dir, img_size, batch_size=32)

# Perform TTA prediction
print("\nExecuting Test Time Augmentation...")
tta_predictions, individual_preds = predict_with_tta(model, tta_test_datasets)

# Get final predictions and true labels
tta_pred_classes = np.argmax(tta_predictions, axis=1)
y_true_tta = tta_test_datasets[0].classes  # All datasets have same order

# Calculate TTA accuracy
tta_accuracy = accuracy_score(y_true_tta, tta_pred_classes)
    
# Calculate standard test accuracy for comparison
standard_predictions = model.predict(test_ds, verbose=0)
standard_pred_classes = np.argmax(standard_predictions, axis=1)
standard_accuracy = accuracy_score(test_ds.classes, standard_pred_classes)

print(f"\nPERFORMANCE RESULTS:")
print(f"Standard Test Accuracy: {standard_accuracy*100:.3f}%")
print(f"TTA Enhanced Accuracy: {tta_accuracy*100:.3f}%")
print(f"Performance Improvement: +{(tta_accuracy*100 - standard_accuracy*100):.3f}%")

# %%
# Detailed TTA metrics
tta_precision = precision_score(y_true_tta, tta_pred_classes, average='weighted')
tta_recall = recall_score(y_true_tta, tta_pred_classes, average='weighted')
tta_f1 = f1_score(y_true_tta, tta_pred_classes, average='weighted')

print(f"\nTTA Enhanced Metrics:")
print(f"  - Weighted Precision: {tta_precision:.4f}")
print(f"  - Weighted Recall: {tta_recall:.4f}")
print(f"  - Weighted F1-score: {tta_f1:.4f}")

# Confidence analysis
individual_confidences = [np.max(pred, axis=1).mean() for pred in individual_preds]
ensemble_confidence = np.max(tta_predictions, axis=1).mean()

print(f"\nConfidence Analysis:")
for i, conf in enumerate(individual_confidences):
    print(f"  - Augmentation {i+1} confidence: {conf:.4f}")
print(f"  - Ensemble confidence: {ensemble_confidence:.4f}")

# Save TTA results
tta_results = {
    'tta_accuracy': tta_accuracy,
    'tta_precision': tta_precision,
    'tta_recall': tta_recall,
    'tta_f1': tta_f1,
    'ensemble_confidence': ensemble_confidence,
    'individual_confidences': individual_confidences
}

print(f"\nTTA evaluation completed! Benchmark accuracy: {tta_accuracy*100:.3f}%")

# %%
# Training visualization
def plot_complete_training_analysis(history_dict, stage1_epochs, stage2_epochs):
    """
    Creates visualization of the 3-stage training process
    """
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(18, 12))
    
    epochs = range(1, len(history_dict['accuracy']) + 1)
    stage3_start = stage1_epochs + stage2_epochs
    
    # Plot 1: Accuracy with stage annotations
    ax1.plot(epochs, history_dict['accuracy'], 'b-', linewidth=2, label='Training Accuracy')
    ax1.plot(epochs, history_dict['val_accuracy'], 'b--', linewidth=2, label='Validation Accuracy')
    
    ax1.axvline(x=stage1_epochs, color='red', linestyle=':', linewidth=2, alpha=0.8, label='Stage 2 starts')
    ax1.axvline(x=stage3_start, color='purple', linestyle=':', linewidth=2, alpha=0.8, label='Stage 3 starts')
    
    ax1.axvspan(0, stage1_epochs, alpha=0.1, color='blue', label='Stage 1: Feature Extraction')
    ax1.axvspan(stage1_epochs, stage3_start, alpha=0.1, color='green', label='Stage 2: Fine-tuning (30 layers)')
    ax1.axvspan(stage3_start, len(epochs), alpha=0.1, color='orange', label='Stage 3: Ultra Fine-tuning (50 layers)')
    
    ax1.set_title('Training Accuracy Progression (3-Stage Training)', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(loc='lower right', fontsize=10)
    ax1.grid(True, alpha=0.3)
    ax1.set_ylim(0.7, 1.0)
    
    # Plot 2: Loss with stage annotations
    ax2.plot(epochs, history_dict['loss'], 'r-', linewidth=2, label='Training Loss')
    ax2.plot(epochs, history_dict['val_loss'], 'r--', linewidth=2, label='Validation Loss')
    
    ax2.axvline(x=stage1_epochs, color='red', linestyle=':', linewidth=2, alpha=0.8)
    ax2.axvline(x=stage3_start, color='purple', linestyle=':', linewidth=2, alpha=0.8)
    
    ax2.axvspan(0, stage1_epochs, alpha=0.1, color='blue')
    ax2.axvspan(stage1_epochs, stage3_start, alpha=0.1, color='green')
    ax2.axvspan(stage3_start, len(epochs), alpha=0.1, color='orange')
    
    ax2.set_title('Training Loss Progression (3-Stage Training)', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(loc='upper right', fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    # Plot 3: Accuracy improvement analysis
    val_acc = history_dict['val_accuracy']
    stage1_best = max(val_acc[:stage1_epochs])
    stage2_best = max(val_acc[stage1_epochs:stage3_start])
    stage3_best = max(val_acc[stage3_start:])
    
    stages = ['Stage 1\n(Feature Extraction)', 'Stage 2\n(Fine-tuning 30L)', 'Stage 3\n(Ultra Fine-tuning 50L)']
    accuracies = [stage1_best, stage2_best, stage3_best]
    
    bars = ax3.bar(stages, accuracies, color=['lightblue', 'lightgreen', 'lightyellow'], 
                   edgecolor='black', linewidth=1.5)
    
    for bar, acc in zip(bars, accuracies):
        height = bar.get_height()
        ax3.text(bar.get_x() + bar.get_width()/2., height + 0.001,
                f'{acc:.4f}', ha='center', va='bottom', fontweight='bold')
    
    ax3.set_title('Best Validation Accuracy by Stage', fontsize=14, fontweight='bold')
    ax3.set_ylabel('Validation Accuracy')
    ax3.set_ylim(0.85, 1.0)
    ax3.grid(True, alpha=0.3, axis='y')
    
    # Plot 4: Smoothed learning curves
    window = 3
    train_acc_smooth = pd.Series(history_dict['accuracy']).rolling(window=window, center=True).mean()
    val_acc_smooth = pd.Series(history_dict['val_accuracy']).rolling(window=window, center=True).mean()
    
    ax4.plot(epochs, train_acc_smooth, 'b-', linewidth=3, label='Training (smoothed)', alpha=0.8)
    ax4.plot(epochs, val_acc_smooth, 'orange', linewidth=3, label='Validation (smoothed)', alpha=0.8)
    ax4.plot(epochs, history_dict['accuracy'], 'b-', linewidth=1, alpha=0.3, label='Training (raw)')
    ax4.plot(epochs, history_dict['val_accuracy'], 'r--', linewidth=1, alpha=0.3, label='Validation (raw)')
    
    ax4.axvline(x=stage1_epochs, color='red', linestyle=':', linewidth=2, alpha=0.8)
    ax4.axvline(x=stage3_start, color='purple', linestyle=':', linewidth=2, alpha=0.8)
    
    ax4.set_title('Smoothed Learning Curves', fontsize=14, fontweight='bold')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Accuracy')
    ax4.legend(fontsize=10)
    ax4.grid(True, alpha=0.3)
    ax4.set_ylim(0.8, 1.0)
    
    plt.tight_layout(pad=3.0)
    
    # Add overall title
    fig.suptitle('Complete 3-Stage Training Analysis: DenseNet201 Kidney Classification', 
                 fontsize=16, fontweight='bold', y=0.98)
    
    return fig

# Create the visualization
if 'total_history' in locals():
    stage1_end = len(history.history['loss'])
    stage2_length = 15
    
    fig = plot_complete_training_analysis(total_history, stage1_end, stage2_length)
    
    plt.savefig(results_path + 'Complete_3Stage_Training_Analysis.png', 
                dpi=300, bbox_inches='tight', facecolor='white')
    plt.show()
    
    # Training summary
    total_epochs = len(total_history['loss'])
    final_train_acc = total_history['accuracy'][-1]
    final_val_acc = total_history['val_accuracy'][-1]
    best_val_acc = max(total_history['val_accuracy'])
    
    print(f"Total training epochs: {total_epochs}")
    print(f"Final training accuracy: {final_train_acc:.4f}")
    print(f"Final validation accuracy: {final_val_acc:.4f}")
    print(f"Best validation accuracy: {best_val_acc:.4f}")
    if 'tta_accuracy' in locals():
        print(f"Test accuracy (TTA enhanced): {tta_accuracy*100:.3f}%")
    
else:
    print("Complete training history not available. Run Stage 3 training first.")
# Out:
# Creating comprehensive training visualization...
# \n======================================================================
# FINAL TRAINING SUMMARY
# ======================================================================
# Total training epochs:           30
# Final training accuracy:         0.9862
# Final validation accuracy:       0.9718
# Best validation accuracy:        0.9750
# Test accuracy (standard):        97.998%
# Test accuracy (TTA enhanced):    99.440%
# ======================================================================

# %%
# Dataset balance analysis
def analyze_dataset_balance(train_dir, val_dir, test_dir, classes):
    """
    Analysis of dataset balance across train/val/test splits
    """
    splits = {'Train': train_dir, 'Validation': val_dir, 'Test': test_dir}
    
    print("Class Distribution Analysis:")
    print("=" * 50)
    
    total_samples = {'Train': 0, 'Validation': 0, 'Test': 0}
    class_counts = {split: {cls: 0 for cls in classes} for split in splits.keys()}
    
    # Count samples in each split and class
    for split_name, split_dir in splits.items():
        print(f"\n{split_name} Set:")
        split_total = 0
        
        for class_name in classes:
            class_dir = os.path.join(split_dir, class_name)
            if os.path.exists(class_dir):
                count = len([f for f in os.listdir(class_dir) 
                           if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
                class_counts[split_name][class_name] = count
                split_total += count
                print(f"  {class_name:8}: {count:4d} samples")
        
        total_samples[split_name] = split_total
        print(f"  {'Total':8}: {split_total:4d} samples")
    
    # Calculate percentages and imbalance metrics
    print(f"\nClass Distribution Percentages:")
    print("=" * 50)
    
    imbalance_ratios = {}
    for split_name in splits.keys():
        print(f"\n{split_name} Set Percentages:")
        split_total = total_samples[split_name]
        
        if split_total > 0:
            percentages = {}
            for class_name in classes:
                count = class_counts[split_name][class_name]
                percentage = (count / split_total) * 100
                percentages[class_name] = percentage
                print(f"  {class_name:8}: {count:4d} ({percentage:5.1f}%)")
            
            # Calculate imbalance ratio
            counts = [class_counts[split_name][cls] for cls in classes if class_counts[split_name][cls] > 0]
            if counts:
                imbalance_ratio = max(counts) / min(counts)
                imbalance_ratios[split_name] = imbalance_ratio
                print(f"  Imbalance Ratio: {imbalance_ratio:.2f}:1 (max/min)")
    
    return class_counts, total_samples, imbalance_ratios

def create_balance_visualization(class_counts, classes):
    """
    Create visualizations for dataset balance analysis
    """
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    splits = ['Train', 'Validation', 'Test']
    colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']
    
    # Plot 1: Grouped bar chart
    x = np.arange(len(classes))
    width = 0.25
    
    train_counts = [class_counts['Train'][cls] for cls in classes]
    val_counts = [class_counts['Validation'][cls] for cls in classes]
    test_counts = [class_counts['Test'][cls] for cls in classes]
    
    ax1.bar(x - width, train_counts, width, label='Train', color='skyblue', alpha=0.8)
    ax1.bar(x, val_counts, width, label='Validation', color='lightcoral', alpha=0.8)
    ax1.bar(x + width, test_counts, width, label='Test', color='lightgreen', alpha=0.8)
    
    ax1.set_xlabel('Classes')
    ax1.set_ylabel('Number of Samples')
    ax1.set_title('Sample Distribution by Class and Split')
    ax1.set_xticks(x)
    ax1.set_xticklabels(classes)
    ax1.legend()
    ax1.grid(True, alpha=0.3, axis='y')
    
    # Add value labels on bars
    for i, (train, val, test) in enumerate(zip(train_counts, val_counts, test_counts)):
        ax1.text(i - width, train + 20, str(train), ha='center', va='bottom', fontsize=9)
        ax1.text(i, val + 10, str(val), ha='center', va='bottom', fontsize=9)
        ax1.text(i + width, test + 10, str(test), ha='center', va='bottom', fontsize=9)
    
    # Plot 2: Pie chart for train set
    train_counts_pie = [class_counts['Train'][cls] for cls in classes]
    ax2.pie(train_counts_pie, labels=classes, autopct='%1.1f%%', colors=colors, startangle=90)
    ax2.set_title('Training Set Class Distribution')
    
    # Plot 3: Imbalance ratio visualization
    splits_for_ratio = ['Train', 'Validation', 'Test']
    ratios = []
    for split in splits_for_ratio:
        counts = [class_counts[split][cls] for cls in classes if class_counts[split][cls] > 0]
        if counts:
            ratio = max(counts) / min(counts)
            ratios.append(ratio)
        else:
            ratios.append(1.0)
    
    bars = ax3.bar(splits_for_ratio, ratios, color=['skyblue', 'lightcoral', 'lightgreen'], alpha=0.7)
    ax3.set_ylabel('Imbalance Ratio (max/min)')
    ax3.set_title('Class Imbalance Across Splits')
    ax3.axhline(y=1.5, color='orange', linestyle='--', alpha=0.7, label='Moderate Imbalance (1.5:1)')
    ax3.axhline(y=2.0, color='red', linestyle='--', alpha=0.7, label='High Imbalance (2:1)')
    ax3.legend()
    ax3.grid(True, alpha=0.3, axis='y')
    
    # Add value labels
    for bar, ratio in zip(bars, ratios):
        height = bar.get_height()
        ax3.text(bar.get_x() + bar.get_width()/2., height + 0.05,
                f'{ratio:.2f}:1', ha='center', va='bottom', fontweight='bold')
    
    # Plot 4: Combined totals
    total_by_class = [sum(class_counts[split][cls] for split in splits_for_ratio) for cls in classes]
    bars = ax4.bar(classes, total_by_class, color=colors, alpha=0.7)
    ax4.set_xlabel('Classes')
    ax4.set_ylabel('Total Samples')
    ax4.set_title('Total Samples per Class (All Splits Combined)')
    ax4.grid(True, alpha=0.3, axis='y')
    
    # Add value labels
    for bar, count in zip(bars, total_by_class):
        height = bar.get_height()
        ax4.text(bar.get_x() + bar.get_width()/2., height + 20,
                str(count), ha='center', va='bottom', fontweight='bold')
    
    plt.tight_layout()
    return fig

# Perform the analysis
class_counts, total_samples, imbalance_ratios = analyze_dataset_balance(train_dir, val_dir, test_dir, classes)

# Create visualization
fig = create_balance_visualization(class_counts, classes)
plt.savefig(results_path + 'Dataset_Balance_Analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# Analysis summary
overall_counts = [sum(class_counts[split][cls] for split in ['Train', 'Validation', 'Test']) for cls in classes]
overall_total = sum(overall_counts)
overall_imbalance = max(overall_counts) / min(overall_counts) if min(overall_counts) > 0 else float('inf')

print(f"\nOverall Dataset Statistics:")
print(f"  Total samples: {overall_total}")
for cls, count in zip(classes, overall_counts):
    percentage = (count / overall_total) * 100
    print(f"  {cls}: {count} samples ({percentage:.1f}%)")
print(f"  Overall imbalance ratio: {overall_imbalance:.2f}:1")
# Out:
# ======================================================================
# DATASET BALANCE ANALYSIS - Checking class distribution
# ======================================================================
# Class Distribution Analysis:
# ==================================================
#
# Train Set:
#   Cyst    : 2967 samples
#   Normal  : 4061 samples
#   Stone   : 1101 samples
#   Tumor   : 1826 samples
#   Total   : 9955 samples
#
# Validation Set:
#   Cyst    :  370 samples
#   Normal  :  507 samples
#   Stone   :  137 samples
#   Tumor   :  228 samples
#   Total   : 1242 samples
#
# Test Set:
#   Cyst    :  372 samples
#   Normal  :  509 samples
#   Stone   :  139 samples
#   Tumor   :  229 samples
#   Total   : 1249 samples
#
# ==================================================
# Class Distribution Percentages:
# ==================================================
#
# Train Set Percentages:
#   Cyst    : 2967 ( 29.8%)
#   Normal  : 4061 ( 40.8%)
#   Stone   : 1101 ( 11.1%)
#   Tumor   : 1826 ( 18.3%)
#   Imbalance Ratio: 3.69:1 (max/min)
#
# Validation Set Percentages:
#   Cyst    :  370 ( 29.8%)
#   Normal  :  507 ( 40.8%)
#   Stone   :  137 ( 11.0%)
#   Tumor   :  228 ( 18.4%)
#   Imbalance Ratio: 3.70:1 (max/min)
#
# Test Set Percentages:
#   Cyst    :  372 ( 29.8%)
#   Normal  :  509 ( 40.8%)
#   Stone   :  139 ( 11.1%)
#   Tumor   :  229 ( 18.3%)
#   Imbalance Ratio: 3.66:1 (max/min)
# ======================================================================
# BALANCE ANALYSIS SUMMARY & RECOMMENDATIONS
# ======================================================================
# Overall Dataset Statistics:
#   Total samples: 12446
#   Cyst: 3709 samples (29.8%)
#   Normal: 5077 samples (40.8%)
#   Stone: 1377 samples (11.1%)
#   Tumor: 2283 samples (18.3%)
#   Overall imbalance ratio: 3.69:1
#
# Recommendations based on current 97.998% accuracy:
# 🔴 HIGH IMBALANCE DETECTED (ratio > 2.0:1)
#    → Dataset balancing STRONGLY recommended
#    → Current high accuracy might be misleading
#    → Implement data augmentation or resampling
#
# For paper publication:
#   1. Include this balance analysis in your methodology
#   2. Report per-class metrics (precision, recall, F1)
#   3. Consider stratified evaluation
#   4. Implement balanced training as ablation study
#   5. Compare balanced vs imbalanced results
# ======================================================================

# %%
# Per-class performance analysis
def detailed_per_class_analysis(model, test_ds, classes):
    """
    Detailed analysis of per-class performance to assess imbalance impact
    """
    print("Analyzing per-class performance...")
    
    # Get predictions
    predictions = model.predict(test_ds, verbose=0)
    y_pred = np.argmax(predictions, axis=1)
    y_true = test_ds.classes
    
    # Calculate per-class metrics
    precision_per_class = precision_score(y_true, y_pred, average=None, labels=range(len(classes)))
    recall_per_class = recall_score(y_true, y_pred, average=None, labels=range(len(classes)))
    f1_per_class = f1_score(y_true, y_pred, average=None, labels=range(len(classes)))
    
    # Get class counts in test set
    test_class_counts = np.bincount(y_true)
    
    print(f"\nPER-CLASS PERFORMANCE ANALYSIS:")
    print("=" * 60)
    print(f"{'Class':10} {'Count':8} {'Precision':10} {'Recall':8} {'F1-Score':8} {'Status':12}")
    print("=" * 60)
    
    imbalance_issues = []
    
    for i, class_name in enumerate(classes):
        if i < len(test_class_counts):
            count = test_class_counts[i]
            prec = precision_per_class[i] if i < len(precision_per_class) else 0
            rec = recall_per_class[i] if i < len(recall_per_class) else 0
            f1 = f1_per_class[i] if i < len(f1_per_class) else 0
            
            # Determine if this class has issues
            if prec < 0.95 or rec < 0.95 or f1 < 0.95:
                status = "NEEDS HELP"
                imbalance_issues.append(class_name)
            else:
                status = "EXCELLENT"
            
            print(f"{class_name:10} {count:8d} {prec:10.4f} {rec:8.4f} {f1:8.4f} {status:12}")
    
    print("=" * 60)
    
    if not imbalance_issues:
        print("ALL CLASSES PERFORMING EXCELLENTLY!")
        return False, imbalance_issues
    else:
        print(f"CLASSES NEEDING IMPROVEMENT: {', '.join(imbalance_issues)}")
        return True, imbalance_issues

# Run the per-class analysis
needs_improvement, problem_classes = detailed_per_class_analysis(model, test_ds, classes)

# %%
# Bayesian optimization for optimal class weights
import keras_tuner as kt

# Helper function for weighted generator
def create_weighted_generator(data_generator, class_weights_dict):
    while True:
        x, y = next(data_generator)
        sample_weights = np.array([class_weights_dict.get(int(label), 1.0) for label in y])
        yield x, y, sample_weights

# Hypermodel for class weight optimization
def build_hypermodel(hp):
    class_weights_hp = {
        0: hp.Float('weight_cyst', min_value=1.0, max_value=4.0, step=0.5),
        1: 1.0,  # Baseline class
        2: hp.Float('weight_stone', min_value=2.0, max_value=8.0, step=1.0),
        3: hp.Float('weight_tumor', min_value=1.0, max_value=4.0, step=0.5)
    }
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    model.class_weights_hp = class_weights_hp
    return model

# Custom tuner for weighted data
class WeightedTuner(kt.BayesianOptimization):
    def run_trial(self, trial, *args, **kwargs):
        hp = trial.hyperparameters
        model = self.hypermodel.build(hp)
        
        weighted_train_gen = create_weighted_generator(train_ds, model.class_weights_hp)

        return super().run_trial(
            trial,
            weighted_train_gen,
            *args,
            steps_per_epoch=len(train_ds),
            **kwargs
        )

# Setup and run Bayesian optimization
tuner_dir = os.path.join(results_path, 'class_weight_tuning_bayesian')
tuner = WeightedTuner(
    build_hypermodel,
    objective='val_accuracy',
    max_trials=15,
    executions_per_trial=1,
    directory=tuner_dir,
    project_name='kidney_weights',
    overwrite=True
)

print("Starting Bayesian optimization for optimal class weights...")

try:
    tuner.search(
        epochs=3,
        validation_data=valid_ds,
        validation_steps=len(valid_ds),
        callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2)]
    )

    # Get best weights
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
    optimal_weights = {
        0: best_hps.get('weight_cyst'),
        1: 1.0,
        2: best_hps.get('weight_stone'),
        3: best_hps.get('weight_tumor')
    }

    print("\nOptimal Class Weights Found:")
    for i, cls in enumerate(classes):
        print(f"  - {cls}: {optimal_weights.get(i, 1.0):.2f}")

    # Final training with optimal weights
    backup_path = os.path.join(results_path, '_Pre_OptimalBalance_Backup.keras')
    model.save(backup_path)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=5e-7),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    final_train_gen = create_weighted_generator(train_ds, optimal_weights)

    current_epochs = len(total_history['loss']) if 'total_history' in locals() else len(history.history['loss'])

    final_history = model.fit(
        final_train_gen,
        steps_per_epoch=len(train_ds),
        epochs=current_epochs + 5,
        initial_epoch=current_epochs,
        validation_data=valid_ds,
        validation_steps=len(valid_ds),
        callbacks=[
            tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True, min_delta=0.0001)
        ],
        verbose=1
    )

    # Final evaluation
    new_loss, new_acc = model.evaluate(test_ds)
    print(f"\nFinal Test Accuracy after optimization: {new_acc*100:.4f}%")

    final_model_path = os.path.join(results_path, '_OptimallyBalanced_Final.keras')
    model.save(final_model_path)

    # Update training history
    if 'total_history' in locals():
        for key in final_history.history.keys():
            total_history[key].extend(final_history.history[key])

except Exception as e:
    print(f"Error during optimization: {e}")

print("Class weight optimization process finished.")

# %%
plt.figure(figsize=(15, 5))

# Use total_history if available (after fine-tuning), otherwise use history
plot_history = total_history if 'total_history' in locals() else history.history
initial_epochs = len(history.history['loss']) if 'total_history' in locals() else 0

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(plot_history['loss'], label='train_loss')
plt.plot(plot_history['val_loss'], label='val_loss')
if initial_epochs > 0:
    plt.axvline(x=initial_epochs-1, color='red', linestyle='--', alpha=0.7, label='Fine-tuning starts')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs (Full Training)')
plt.grid(True)

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(plot_history['accuracy'], label='train_accuracy')
plt.plot(plot_history['val_accuracy'], label='val_accuracy')
if initial_epochs > 0:
    plt.axvline(x=initial_epochs-1, color='red', linestyle='--', alpha=0.7, label='Fine-tuning starts')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs (Full Training)')
plt.grid(True)

plt.tight_layout()

# Save the figure
plt.savefig(results_path + 'Loss_accuracy_FineTuned.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# Final evaluation with Test Time Augmentation
print("PERFORMING FINAL EVALUATION WITH TEST TIME AUGMENTATION")

# Load the final optimized model
final_model_path = os.path.join(results_path, '_OptimallyBalanced_Final.keras')
try:
    final_model = tf.keras.models.load_model(final_model_path)
    print("Final model loaded successfully.")
except Exception as e:
    print(f"Could not load final model: {e}")
    final_model = model  # Use current model if loading fails

if final_model and 'tta_test_datasets' in locals() and 'predict_with_tta' in locals():
    print("\nExecuting Test Time Augmentation on final model...")
    
    # Perform TTA prediction
    tta_predictions, _ = predict_with_tta(final_model, tta_test_datasets, verbose=True)

    # Get final predictions and true labels
    tta_pred_classes = np.argmax(tta_predictions, axis=1)
    y_true_tta = tta_test_datasets[0].classes

    # Calculate final TTA accuracy
    final_tta_accuracy = accuracy_score(y_true_tta, tta_pred_classes)

    print(f"\nFINAL RESULTS:")
    print(f"Standard Test Accuracy: {new_acc*100:.4f}%")
    print(f"TTA Enhanced Accuracy: {final_tta_accuracy*100:.4f}%")
    print(f"Performance Improvement: +{(final_tta_accuracy - new_acc)*100:.4f}%")
        
else:
    print("TTA functions or datasets not available.")

# %%
# Use total_history if available (after fine-tuning), otherwise use history
plot_history = total_history if 'total_history' in locals() else history.history
initial_epochs = len(history.history['loss']) if 'total_history' in locals() else 0

epochs = range(1, len(plot_history['accuracy']) + 1)
plt.figure(figsize=(12, 8))

# Plot accuracy
plt.plot(epochs, plot_history['accuracy'], 'b-', label='Training Accuracy', linewidth=2)
plt.plot(epochs, plot_history['val_accuracy'], 'b--', label='Validation Accuracy', linewidth=2)

# Plot loss
plt.plot(epochs, plot_history['loss'], 'r-', label='Training Loss', linewidth=2)
plt.plot(epochs, plot_history['val_loss'], 'r--', label='Validation Loss', linewidth=2)

# Add vertical line to show where fine-tuning started
if initial_epochs > 0:
    plt.axvline(x=initial_epochs, color='green', linestyle=':', linewidth=2, alpha=0.8, 
                label=f'Fine-tuning starts (Epoch {initial_epochs})')

plt.title('Training and Validation Accuracy and Loss\n(Complete Training with Fine-tuning)', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend(loc='center right')
plt.grid(True, alpha=0.3)

# Add text annotations
if initial_epochs > 0:
    plt.text(initial_epochs//2, 0.1, 'Stage 1:\nFeature Extraction', 
             horizontalalignment='center', bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue"))
    plt.text(initial_epochs + (len(epochs)-initial_epochs)//2, 0.1, 'Stage 2:\nFine-tuning', 
             horizontalalignment='center', bbox=dict(boxstyle="round,pad=0.3", facecolor="lightgreen"))

plt.tight_layout()

plt.savefig(results_path + 'Loss_accuracy_Complete_FineTuned.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
#1- Evaluate the model on the test data using `evaluate`
_, accuracy = model.evaluate(test_ds, batch_size=32)
print()
print('evaluation accuracy is :  %.3f' % (accuracy * 100.0))
print()
# Out:
# c:\Users\pyzap\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.9960 - loss: 0.0201
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step - accuracy: 0.9960 - loss: 0.0201
#
# evaluation accuracy is :  97.998
#
#
# evaluation accuracy is :  97.998

# %%
predictions            = model.predict(test_ds)
y_test                 = test_ds.classes

y_pred                 = np.argmax(predictions, axis=1)  # Get the index of the maximum value
cm                     = confusion_matrix(y_test, y_pred)

cmd                    = ConfusionMatrixDisplay(confusion_matrix=cm)
cmd.plot(include_values= True, cmap='viridis', ax=None, xticks_rotation='horizontal')

# Save the figure (Fixed typo: resuts_path -> results_path)
plt.savefig(results_path + 'Confusion Matrix.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 150s 3s/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 150s 3s/step

# %%
predictions_test = model.predict(test_ds)
y_test           = test_ds.classes

predicted_classes = [np.argmax(pred) for pred in predictions_test]

print(classification_report(y_test, predicted_classes))

report            = classification_report(y_test, predicted_classes, target_names=classes, output_dict=True)
metrics           = {label: report[label] for label in classes if label in report}
precision_list    = [metrics[label]['precision'] for label in classes]
recall_list       = [metrics[label]['recall']    for label in classes]
f1_score_list     = [metrics[label]['f1-score']  for label in classes]

data = {
        'Precision': precision_list,
        'Recall'   : recall_list,
        'F1-Score' : f1_score_list
        }

df   = pd.DataFrame(data, index=classes)

plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5)
plt.title('Classification Report')
plt.xlabel('Metrics')
plt.ylabel('Classes')

plt.savefig(results_path + 'Classification Report.png', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 128s 3s/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 128s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       372
#            1       0.98      1.00      0.99       509
#            2       0.99      0.96      0.97       139
#            3       1.00      0.92      0.96       229
#
#     accuracy                           0.98      1249
#    macro avg       0.98      0.97      0.98      1249
# weighted avg       0.98      0.98      0.98      1249
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       372
#            1       0.98      1.00      0.99       509
#            2       0.99      0.96      0.97       139
#            3       1.00      0.92      0.96       229
#
#     accuracy                           0.98      1249
#    macro avg       0.98      0.97      0.98      1249
# weighted avg       0.98      0.98      0.98      1249

# %%
y_pred_probs = model.predict(test_ds)
y_pred       = np.argmax(y_pred_probs, axis=1)
y_true       = test_ds.classes

# Calculate metrics with proper averaging for multi-class
precision_weighted    = precision_score(y_true, y_pred, average='weighted')
recall_weighted       = recall_score(y_true, y_pred, average='weighted')
f1_weighted           = f1_score(y_true, y_pred, average='weighted')

print(f"Weighted Precision: {precision_weighted:.4f}")
print(f"Weighted Recall   : {recall_weighted:.4f}")
print(f"Weighted F1-score : {f1_weighted:.4f}")

# Also show macro averages
precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro    = recall_score(y_true, y_pred, average='macro')
f1_macro        = f1_score(y_true, y_pred, average='macro')

print(f"\nMacro Precision: {precision_macro:.4f}")
print(f"Macro Recall   : {recall_macro:.4f}")
print(f"Macro F1-score : {f1_macro:.4f}")
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 130s 3s/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 130s 3s/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 8
#       6 precision_weighted    = precision_score(y_true, y_pred, average='weighted')
#       7 recall_weighted       = recall_score(y_true, y_pred, average='weighted')
# ----> 8 f1_weighted           = f1_score(y_true, y_pred, average='weighted')
#      10 print(f"Weighted Precision: {precision_weighted:.4f}")
#      11 print(f"Weighted Recall   : {recall_weighted:.4f}")
#
# TypeError: 'list' object is not callable

# %%
# Extract true label from image path
def extract_true_label(img_path):
    print(img_path)
    folder_name = os.path.basename(os.path.dirname(img_path))
    print(folder_name)

    if "Cyst" in folder_name:
        return "Cyst"
    elif "Normal" in folder_name:
        return "Normal"
    elif "Stone" in folder_name:
        return "Stone"
    elif "Tumor" in folder_name:
        return "Tumor"

    return "Unknown"

# Load and preprocess image using the SAME pipeline as training
def load_and_preprocess_image(img_path, target_size):
    if img_path.startswith('http'):
        response = requests.get(img_path)
        img = Image.open(BytesIO(response.content)).convert("RGB")
    else:
        img = image.load_img(img_path)

    # Resize image explicitly
    img = img.resize(target_size)

    # Convert to array 
    img_array = image.img_to_array(img)
    
    # CRITICAL: Apply the SAME preprocessing pipeline as training
    img_array = kidney_preprocessing_pipeline(img_array)
    
    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    
    return img, img_array

# %%
# Image path (URL or local)
img_path = test_dir + '/Cyst/Cyst- (100).jpg'#Cyst- (4).jpg

# Extract true label
true_label     = extract_true_label(img_path)

# Load and preprocess image
img, img_array = load_and_preprocess_image(img_path, img_size)

# Make prediction
pred = model.predict(img_array)
pred_index = np.argmax(pred, axis=1)

class_labels = ["Cyst", "Normal", "Stone", "Tumor"]
predicted_label = class_labels[pred_index[0]]

# Display image
plt.imshow(img)
plt.axis('off')
plt.title(f"True = {true_label} | Predict = {predicted_label}")
plt.show()

# Print result
print(f"True = {true_label}    Predict = {predicted_label}")
# Out:
# E:\____My2024 Work\___Research_Abo\Now\Kidney Classification_Now\dataset\All\CT_split_Type2\test\Cyst\Cyst- (28).jpg
# Cyst
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# True = Cyst    Predict = Cyst
